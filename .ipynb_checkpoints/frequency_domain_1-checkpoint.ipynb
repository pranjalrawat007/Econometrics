# %% [markdown]
# Cyclical Model of Business Cycle

# %%
import numpy as np
import plotly.express as px

def model(a, ω, θ, T):
    θ = 0 # Phase Shift
    ω = 0.2 # Frequency (2π/Duration)
    a = 2 # Amplitude
    Y = 2*a*np.cos(ω*T+θ)
    return Y

T = np.arange(100)
fig = px.line(y=model(1, 0.2, 0, T),x=T)
fig.add_trace(px.line(y=model(1, 0.2, 0.5, T),x=T))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [3], line 13
#      11 T = np.arange(100)
#      12 fig = px.line(y=model(1, 0.2, 0, T),x=T)
# ---> 13 fig.add_trace(px.line(y=model(1, 0.2, 0.5, T),x=T))
#      14 fig.show()
#
# File /usr/local/lib/python3.10/site-packages/plotly/graph_objs/_figure.py:887, in Figure.add_trace(self, trace, row, col, secondary_y, exclude_empty_subplots)
#     812 def add_trace(
#     813     self, trace, row=None, col=None, secondary_y=None, exclude_empty_subplots=False
#     814 ) -> "Figure":
#     815     """
#     816
#     817     Add a trace to the figure
#    (...)
#     885
#     886     """
# --> 887     return super(Figure, self).add_trace(
#     888         trace, row, col, secondary_y, exclude_empty_subplots
#     889     )
#
# ...

# %%
M = 3
ω1 = 0.03
ω2 = 0.20
ω3 = 0.47
